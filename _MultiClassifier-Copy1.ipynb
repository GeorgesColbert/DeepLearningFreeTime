# %%
import pandas as pd
import numpy as np
import json



json_file_path = "clearstep-prod-symptoms-to-output-dump.json"


with open(json_file_path, 'r') as j:
     contents = json.loads(j.read())

# %% [markdown]
# __Mapping out Class names__

# %%
cldata = pd.read_excel('Clearstep NLP - Bank of Phrases.xlsx',sheet_name='Copy of Bank of Phrases-Clearst')
cldata.head()
# Out:
#                  abdominal-pain animal-or-human-bite  \
# 0              My stomach hurts        A dog bit me
# 1                  Stomach pain         A cat bit me
# 2            Pain in my stomach       A bunny bit me
# 3            Sharp stomach pain       A horse bit me
# 4  Burning sensation in stomach         A pig bit me
#
#                        arm-injury                         arm-pain  \
# 0                     Fell on arm          Arm is purple and tight
# 1  Arm hurts when I raise my hand  Arm feels heavy after waking up
# 2      Tingling feeling in my arm                 Bone ache in arm
# 3                     Arm is numb                       Bicep pain
# 4                  Can't feel arm                      Tricep pain
#
#                   asthma-attack                    athletes-foot  \
# 0               Hard to breathe                     Rash on foot
# 1                      Wheezing                  Redness on foot
# ...

# %%
pd.read_csv('[Georges] Bank of Phrases.csv',nrows=5)
# Out:
#                  abdominal-pain animal-or-human-bite  \
# 0  My stomach hurts              A dog bit me
# 1  Stomach pain                  A cat bit me
# 2  Pain in my stomach            A bunny bit me
# 3  Sharp stomach pain            A horse bit me
# 4  Burning sensation in stomach  A pig bit me
#
#                        arm-injury                         arm-pain  \
# 0  Fell on arm                     Arm is purple and tight
# 1  Arm hurts when I raise my hand  Arm feels heavy after waking up
# 2  Tingling feeling in my arm      Bone ache in arm
# 3  Arm is numb                     Bicep pain
# 4  Can't feel arm                  Tricep pain
#
#                   asthma-attack                    athletes-foot  \
# 0  Hard to breathe               Rash on foot
# 1  Wheezing                      Redness on foot
# 2  I start to wheeze when I run  Foot is red and itchy
# 3  Pressure on my lungs          Foot hurts and is red and itchy
# ...

# %%
genclass={
'Abdominal Pain' : ["Abdomen Pain","abdominal-pain"],
'Animal Bite / Animal or Human Bite': ["Animal Bite or Scratch","animal-or-human-bite"],
'Anxious':["Anxious or Nervous","anxiety-nervousness"],
'Arm Injury':["Arm Injury","arm-injury"],
'Asthma Attack':["Asthma Attack","asthma-attack"],
"Athlete's Foot":["Foot Unusual Odor or Bad Smell","athletes-foot"],
'Bee or Yellow Jacket Sting':["Bee, Wasp, or Yellow Jacket Sting","bee-or-yellow-jacket-sting"],
'Blisters':["Skin Blister(s)","blisters"] ,
'Bloody urine':["Hematuria (Blood in Urine)","urine-blood-in"] ,
'Breathing Trouble':["Shortness of Breath","trouble-breathing"] ,
 'Chest Pain':["Chest or Rib Pain","chest-pain"] ,
'Depression':["Sadness","depression"] ,
'Dizziness': ["Dizziness (Lightheaded - Woozy)","dizziness"],
'Ear - fullness, congestion, discharge':["Ear Discharge (Leaking Fluid or Pus)","ear-fullness-congestion-discharge"],
'Eye - pus, discharge, redness':["Eye Discharge (Cloudy Fluid or Pus)","eye-pus-discharge-redness"],
'Eye or eyelid pain':["Eye Pain","eye-or-eyelid-pain"],
'Eye, eyelid swelling':["Eyelid Swelling","eyelid-swelling"],
'Face Injury or Pain':["Face Pain","face-injury-or-pain"],
'Flank pain':["Flank Pain","flank-pain"],
'Foot & ankle injury or ankle pain':["Ankle Pain","foot-and-ankle-injury-or-ankle-pain"],
'Foot pain':["Foot Pain","foot-pain"],
'Frequent urination':["Urination Frequency","frequent-urination"],
'Headache':["Head Pain (Headache)","headache"],
'High blood pressure':["High Blood Pressure","high-blood-pressure"],
'Hives':["Urticaria (Hives)","hives"],
'Insomnia':["Insomnia (Trouble Sleeping)","insomnia"],
'Itchy (localized or widespread)':["Itching - Localized","itch-localized-widespread"],
'Knee Injury or Pain':[["Knee Pain","Knee Injury"],"knee-pain-or-injury"],
'Lymph node problem':["Lymph Node Swelling","lymph-node-problem"],
'Moles and growths':["Skin Moles or Growths","skin-growth-or-mole"],
'Neck pain':["Neck Pain","neck-pain-or-stiffness"],
'Nose Stuffiness / Congestion':["Nose Stuffiness or Congestion","congestion"],
'Pelvic pain':["Pelvic Pain","pelvic-pain"],
'Rectal bleeding':["Rectal Bleeding","rectal-bleeding"],
'Redness or Rash - Widespread and Localized':["Redness or Rash - Localized","rash-or-redness-widespread-or-localized"],
'Shoulder Injury or Pain':[["Shoulder Pain","Shoulder Crooked or Deformed"],"shoulder-pain-or-injury"],
 'Sore Throat':["Throat Pain","sore-throat"],
'Toothache':["Tooth or Gum Pain","toothache"]   
}

# %%
#Count of clearstep class names
data = pd.DataFrame.from_dict(contents, orient='index')

data = data.reset_index()
data.rename(columns={'index':'text'},inplace=True)
data.columns  = ['text','v0','v1','v2','v3','v4','v5','v6','v7','v8','v9','v10','v11','v12','v13','v14','v15','v16','v17']



#How often are some classes showing up in each colum
targets = ['v0','v1','v2','v3','v4','v5','v6','v7','v8','v9','v10','v11','v12','v13','v14','v15','v16','v17']

counting = data[targets].apply(pd.value_counts)
counting.reset_index(inplace=True)
counting.rename(columns={'index':'Clearstep Class'},inplace=True)




#Change all old class names to CL class names
for i in targets:
    data[i].replace(conv,inplace=True)
    
counting = data[targets].apply(pd.value_counts)
counting.reset_index(inplace=True)
counting.rename(columns={'index':'Clearstep Class'},inplace=True)


#Count of every term in that DB
counting['Total Count'] = counting[targets].sum(axis=1)
countings = counting[['Clearstep Class','Total Count']]

# %%
data[data['text'].str.contains('depressed')].sample(15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2d9d2ec95309> in <module>
# ----> 1 data[data['text'].str.contains('depressed')].sample(15)
#
# NameError: name 'data' is not defined

# %%
#Find Class in generated data not int DB data
clclass = cldata.columns
exclass = list(countings['Clearstep Class'])
diffclass = np.setdiff1d(clclass,exclass)

diffclass = list(diffclass)

# %%
clclass
# Out:
# Index(['abdominal-pain', 'animal-or-human-bite', 'arm-injury', 'arm-pain',
#        'asthma-attack', 'athletes-foot', 'back-pain',
#        'bee-or-yellow-jacket-sting', 'trouble-breathing', 'burn', 'chest-pain',
#        'cough', 'headache', 'diarrhea', 'sore-throat', 'runny-nose', 'fever',
#        'congestion', 'weakness-and-fatigue', 'earache',
#        'rash-or-redness-widespread-or-localized', 'dizziness', 'myalgia',
#        'nausea', 'urination-pain', 'anxiety-nervousness',
#        'face-injury-or-pain', 'vomiting', 'ear-fullness-congestion-discharge',
#        'chills', 'eye-pus-discharge-redness', 'eyelid-swelling',
#        'itch-localized-widespread', 'depression', 'toothache',
#        'shoulder-pain-or-injury', 'knee-pain-or-injury', 'leg-pain',
#        'neck-pain-or-stiffness', 'insomnia', 'high-blood-pressure',
#        'foot-pain', 'foot-and-ankle-injury-or-ankle-pain',
#        'skin-growth-or-mole', 'eye-or-eyelid-pain', 'urine-blood-in',
# ...

# %%
tags = pd.unique(data[targets].values.ravel())
counted = {}
for name in tags:
    newname = str(name)+'_Class'
    counted[name] =data[data[targets].eq(name).any(axis=1)].shape[0]
    data[newname] = np.where(data[targets].eq(name).any(axis=1),1,0)

# %%
data.columns
# Out:
# Index(['text', 'v0', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8',
#        ...
#        'eye-foreign-body-or-injury_Class', 'head-lice_Class',
#        'nose-allergy_Class', 'heat-exposure_Class', 'scrotal-swelling_Class',
#        'wound-infection_Class', 'athletes-foot_Class', 'puncture-wound_Class',
#        'sunburn_Class', 'scorpion-sting-north-america_Class'],
#       dtype='object', length=131)

# %%
clclass
# Out:
# Index(['abdominal-pain', 'animal-or-human-bite', 'arm-injury', 'arm-pain',
#        'asthma-attack', 'athletes-foot', 'back-pain',
#        'bee-or-yellow-jacket-sting', 'trouble-breathing', 'burn', 'chest-pain',
#        'cough', 'headache', 'diarrhea', 'sore-throat', 'runny-nose', 'fever',
#        'congestion', 'weakness-and-fatigue', 'earache',
#        'rash-or-redness-widespread-or-localized', 'dizziness', 'myalgia',
#        'nausea', 'urination-pain', 'anxiety-nervousness',
#        'face-injury-or-pain', 'vomiting', 'ear-fullness-congestion-discharge',
#        'chills', 'eye-pus-discharge-redness', 'eyelid-swelling',
#        'itch-localized-widespread', 'depression', 'toothache',
#        'shoulder-pain-or-injury', 'knee-pain-or-injury', 'leg-pain',
#        'neck-pain-or-stiffness', 'insomnia', 'high-blood-pressure',
#        'foot-pain', 'foot-and-ankle-injury-or-ankle-pain',
#        'skin-growth-or-mole', 'eye-or-eyelid-pain', 'urine-blood-in',
# ...

# %%
data.info(null_counts=True,verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18948 entries, 0 to 18947
# Data columns (total 131 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   text                                           18948 non-null  object
#  1   v0                                             18948 non-null  object
#  2   v1                                             9290 non-null   object
#  3   v2                                             4718 non-null   object
#  4   v3                                             2004 non-null   object
#  5   v4                                             781 non-null    object
#  6   v5                                             271 non-null    object
#  7   v6                                             85 non-null     object
#  8   v7                                             43 non-null     object
# ...

# %%
muldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18948 entries, 0 to 18947
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   text                       18948 non-null  object
#  1   depression_Class           18948 non-null  int64
#  2   headache_Class             18948 non-null  int64
#  3   drug-use-and-abuse_Class   18948 non-null  int64
#  4   anxiety-nervousness_Class  18948 non-null  int64
#  5   dizziness_Class            18948 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 888.3+ KB

# %% [markdown]
# # Modeling For _

# %%
clitem = 'burn'
#clitem = clclass[0]
iclass = clitem+'_Class'
cat = [iclass]
muldata = data[['text','headache_Class','fever_Class','sore-throat_Class','anxiety-nervousness_Class','depression_Class','cough_Class','abdominal-pain_Class','congestion_Class','myalgia_Class','back-pain_Class']]
iclass = ['headache_Class','fever_Class','sore-throat_Class','anxiety-nervousness_Class','depression_Class','cough_Class','abdominal-pain_Class','congestion_Class','myalgia_Class','back-pain_Class']
itotal = 'text','depression_Class','headache_Class','drug-use-and-abuse_Class','anxiety-nervousness_Class','dizziness_Class'

z = muldata[(muldata['headache_Class']==1)].sample(800)
limit=z['text']
x = muldata[(muldata['fever_Class']==1)|(muldata['sore-throat_Class']==1)|(muldata['anxiety-nervousness_Class']==1)|(muldata['depression_Class']==1)|(muldata['cough_Class']==1)|(muldata['abdominal-pain_Class']==1)|(muldata['congestion_Class']==1)|(muldata['myalgia_Class']==1)|(muldata['back-pain_Class']==1)]
#x = muldata[(muldata['depression_Class']==1)|(muldata['drug-use-and-abuse_Class']==1)|(muldata['anxiety-nervousness_Class']==1)|(muldata['dizziness_Class']==1)]
x= x[~x['text'].isin(limit)]



w = muldata[(muldata['headache_Class']==0) & (muldata['fever_Class']==0)& (muldata['sore-throat_Class']==0) & (muldata['anxiety-nervousness_Class']==0)& (muldata['depression_Class']==0) & (muldata['cough_Class']==0) & (muldata['abdominal-pain_Class']==0) & (muldata['congestion_Class']==0) & (muldata['myalgia_Class']==0) & (muldata['back-pain_Class']==0)]
w = w.sample(300)

muldata = pd.concat([x,w,z],axis=0)

# %%
data.columns
# Out:
# Index(['text', 'v0', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8',
#        ...
#        'eye-foreign-body-or-injury_Class', 'head-lice_Class',
#        'nose-allergy_Class', 'heat-exposure_Class', 'scrotal-swelling_Class',
#        'wound-infection_Class', 'athletes-foot_Class', 'puncture-wound_Class',
#        'sunburn_Class', 'scorpion-sting-north-america_Class'],
#       dtype='object', length=131)

# %%
muldata[iclass].apply(pd.Series.value_counts)
# Out:
#    headache_Class  fever_Class  sore-throat_Class  anxiety-nervousness_Class  \
# 0            7214         7302               7260                       8768
# 1            2228         2140               2182                        674
#
#    depression_Class  cough_Class  abdominal-pain_Class  congestion_Class  \
# 0              9175         7286                  8372              8039
# 1               267         2156                  1070              1403
#
#    myalgia_Class  back-pain_Class
# 0           7988             8776
# 1           1454              666

# %%
data[['text', 'v0', 'v1', 'v2', 'v3', 'v4', 'v5']][data['text'].str.contains('Depression')].sample(15)
# Out:
#                                                                                                                                                                               text  \
# 2448  Depression anxiety ptsd
# 2442  Depression anxiety
# 2458  Depression, Anxiety, unfocused
# 2432  Depression and Anxiety
# 585   Anxiety, Abuse, PTSD, OCD, Depression
# 2445  Depression anxiety fatigue
# 1681  Chronic pain stimulator. Depression anxiety headaches.
# 2450  Depression fatigue anxiety insomnia
# 2451  Depression lack of motivation
# 2473  Depression, anxiety, sadness
# 2476  Depression, anxiety, tired
# 2485  Depression. Not eating,  does not want to get out of bed.  Lethargic and hopeless feeling
# 2480  Depression, no motivation, anxiety
# 2439  Depression and mood swings period not regular, low iron, i stay cold all the time in winter months if i go outside my body starts to turn purple as soon  as I walk outside
# 545   Anxiety & Depression
#
# ...

# %%
pd.set_option('display.max_colwidth', -1)
itotal = ['text','depression_Class','headache_Class','drug-use-and-abuse_Class','anxiety-nervousness_Class','dizziness_Class']
x = muldata[itotal][muldata['text'].str.contains('Depression')]
#y = game[game['text'].str.contains('headache')]

#x[x['text'].isin(y['text'])]
x
# Out:
# <ipython-input-93-b78725cb8bce>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                                                                                     text  \
# 471    Alcoholism Depression Anxiety
# 545    Anxiety & Depression
# 546    Anxiety & Depression
# 550    Anxiety and Depression
# 551    Anxiety and Depression which I feel has turned me into a reclusive hypochondriac
# ...                                                                                  ...
# 2487   Depression/ anxiety Memory issues
# 2488   Depression/grief / loss
# 3414   Fear, Depression, Anxiety, OCD
# 8478   Mania, Depression, Anxiety, Concentration issues.
# 12358  Stomach Issues, Anxiety and Depression
#
#        depression_Class  headache_Class  drug-use-and-abuse_Class  \
# 471    0                 0               0
# ...

# %%
pd.set_option('display.max_colwidth', -1)
itotal = ['text','depression_Class','headache_Class','drug-use-and-abuse_Class','anxiety-nervousness_Class','dizziness_Class']
x = muldata[itotal][data['text'].str.contains('Depression')]
#y = game[game['text'].str.contains('headache')]

#x[x['text'].isin(y['text'])]
x
# Out:
# <ipython-input-110-217f018b73d9>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
# <ipython-input-110-217f018b73d9>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   x = muldata[itotal][data['text'].str.contains('Depression')]
#                                                                                     text  \
# 471    Alcoholism Depression Anxiety
# 545    Anxiety & Depression
# 546    Anxiety & Depression
# 550    Anxiety and Depression
# 551    Anxiety and Depression which I feel has turned me into a reclusive hypochondriac
# ...                                                                                  ...
# 2487   Depression/ anxiety Memory issues
# 2488   Depression/grief / loss
# 3414   Fear, Depression, Anxiety, OCD
# ...

# %%
from collections import Counter

from imblearn.under_sampling import RandomUnderSampler
# define dataset
X, y = data2['text'],data2[iclass]
# summarize class distribution
print(Counter(y))
# define undersample strategy
X = np.array(X)
X = X.reshape(-1,1)
undersample = RandomUnderSampler(sampling_strategy='majority')
# fit and apply the transform
X, y = undersample.fit_resample(X, y)
print(Counter(y))
# Out:
# Counter({0: 18919, 1: 29})
# Counter({0: 29, 1: 29})

# %%
X = pd.DataFrame(X)
y= pd.DataFrame(y)
data2 = pd.concat([X,y],axis=1)

data2.columns = ['text',iclass]

# %%
import keras



from keras.callbacks import EarlyStopping
from sklearn import preprocessing

from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn import preprocessing
from sklearn.model_selection import train_test_split



X_train, X_test, y_train, y_test = train_test_split(muldata['text'],muldata[iclass],test_size=0.3, random_state=42)

# %%
y_train.head()
# Out:
#        headache_Class  fever_Class  sore-throat_Class  \
# 61                  0            0                  0
# 16633               0            1                  0
# 18162               0            1                  1
# 13391               0            0                  0
# 8122                0            0                  0
#
#        anxiety-nervousness_Class  depression_Class  cough_Class  \
# 61                             0                 0            0
# 16633                          0                 0            0
# 18162                          0                 0            0
# 13391                          0                 0            0
# 8122                           0                 0            0
#
#        abdominal-pain_Class  congestion_Class  myalgia_Class  back-pain_Class
# 61                        1                 0              0                0
# 16633                     0                 0              0                0
# ...

# %%
#Preprocessing text
import string
import nltk 
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')

import gensim



#Transform data

review_lines = list()

#lines = ntrain['text']

lines = X_train

for line in lines:
    tokens = word_tokenize(line)
    
    #convert to lower case
    tokens = [w.lower() for w in tokens]
    
    #remove punctuation form each word
    table = str.maketrans('','',string.punctuation)
    stripped = [w.translate(table) for w in tokens]
    
    #remove remaining tokens that are not alphabetic
    words = [word for word in stripped if word.isalpha()]
   
    #filter out stop words
    stop_words=set(stopwords.words('english'))
    #words = [w for w in words if not w in stop_words]
    review_lines.append(words)
  
    
review_tlines = list()

testlines = X_test

for line in testlines:
    tokens = word_tokenize(line)
    
    #convert to lower case
    tokens = [w.lower() for w in tokens]
    
    #remove punctuation from each word
    table = str.maketrans('','',string.punctuation)
    stripped = [w.translate(table) for w in tokens]
    
    #remove remaining tokens that are not alphabetic
    words = [word for word in stripped if word.isalpha()]
   
    #filter out stop words
    stop_words=set(stopwords.words('english'))
    #words = [w for w in words if not w in stop_words]
    review_tlines.append(words)
      



# Import relevant classes/functions
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical


#review_lines = ntrain.data
#review_tlines = ntest.data




#max length of documents in  training text
max_length2 = max([len(s) for s in review_lines])  
max_length= 180
    
# Create and fit tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(review_lines)

# Prepare the data
prep_data = tokenizer.texts_to_sequences(review_lines)
prep_data = pad_sequences(prep_data, maxlen=max_length,padding='post')



test_data = tokenizer.texts_to_sequences(review_tlines)
test_data = pad_sequences(test_data, maxlen=max_length,padding='post')
# Prepare the labels
prep_labels = y_train
test_labels = y_test




#create a matrix with of word vectors.
word_index = tokenizer.word_index
print('found %s unique tokens' % len(word_index))

num_words= len(word_index) + 1


emwords = np.int(num_words/4.5)
bsize = np.int(X_train.shape[0]/4.5)

print('Embeddings: ',emwords,'Batch Size: ',bsize)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/georgesericcolbert/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/georgesericcolbert/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# found 3125 unique tokens
# Embeddings:  694 Batch Size:  1468

# %%
3025/4
# Out:
# 756.25

# %%
test_labels
# Out:
#        headache_Class  fever_Class  sore-throat_Class  \
# 5457   0               0            0
# 5319   0               0            1
# 11831  0               1            1
# 18242  0               0            1
# 15025  0               0            1
# ...   ..              ..           ..
# 11999  0               0            1
# 6775   0               1            0
# 2605   0               0            0
# 8965   0               0            1
# 3917   0               1            0
#
#        anxiety-nervousness_Class  depression_Class  cough_Class  \
# 5457   0                          1                 0
# 5319   0                          0                 0
# 11831  0                          0                 0
# 18242  0                          0                 0
# 15025  0                          0                 0
# ...   ..                         ..                ..
# 11999  0                          0                 0
# ...

# %%
bsize=1

# %%
from keras.models import Sequential
from keras.layers import Dense,Embedding,LSTM, GRU, Dropout, Bidirectional
from keras.initializers import Constant
from keras.optimizers import SGD
#define model
model = Sequential()

#embedding_layer = Embedding(num_words,EMBEDDING_DIM,embeddings_initializer=Constant(embedding_matrix),input_length=max_length,trainable=False)
#model.add(embedding_layer)

#model.add(Embedding(num_words,400,input_length=max_length,trainable=True))

model.add(Embedding(num_words,emwords,input_length=max_length,trainable=True))
#model.add(LSTM(160, return_sequences=True,activation='relu'))
#model.add(GRU(units=120,return_sequences=True,activation='relu',dropout=0.2,recurrent_dropout=0.15))
model.add(Bidirectional(LSTM(85, return_sequences=False)))

#model.add(GRU(units=73,return_sequences=False,activation='relu',dropout=0.2,recurrent_dropout=0.15))
model.add(Dropout(rate=0.25))

#model.add(LSTM(44, return_sequences=True, dropout=0.2, recurrent_dropout=0.15))
model.add(Dense(10, activation='sigmoid'))

#model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.1, momentum=0.5, clipvalue=4.0), metrics=['accuracy'])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[keras.metrics.Recall()])

earlystop = EarlyStopping(patience=15)

model.fit(prep_data,prep_labels,batch_size=bsize,validation_split=0.2,epochs=80,callbacks = [earlystop])


model.evaluate(test_data, test_labels)
#Best Accuracy so far: 84%
# Out:
# Epoch 1/80
# 4/4 [==============================] - 33s 7s/step - loss: 0.6682 - recall_2: 0.3752 - val_loss: 0.5577 - val_recall_2: 0.0025
# Epoch 2/80
# 4/4 [==============================] - 28s 7s/step - loss: 0.5220 - recall_2: 0.0252 - val_loss: 0.4134 - val_recall_2: 0.0000e+00
# Epoch 3/80
# 4/4 [==============================] - 28s 7s/step - loss: 0.4129 - recall_2: 6.5093e-04 - val_loss: 0.4044 - val_recall_2: 0.0000e+00
# Epoch 4/80
# 4/4 [==============================] - 28s 7s/step - loss: 0.4107 - recall_2: 2.1129e-04 - val_loss: 0.3980 - val_recall_2: 0.0000e+00
# Epoch 5/80
# 4/4 [==============================] - 30s 8s/step - loss: 0.4021 - recall_2: 0.0012 - val_loss: 0.3875 - val_recall_2: 0.0000e+00
# Epoch 6/80
# 4/4 [==============================] - 30s 7s/step - loss: 0.3930 - recall_2: 0.0023 - val_loss: 0.3792 - val_recall_2: 0.0000e+00
# Epoch 7/80
# ...

# %%
X_test.shape

# %%
#pd.options.display.float_format = '{:.3f}'.format
np.set_printoptions(formatter={'float_kind':'{:f}'.format})
model.evaluate(test_data, test_labels)
# Out:
# 14/14 [==============================] - 1s 98ms/step - loss: 0.1174 - recall_1: 0.9405
# [0.11742497980594635, 0.9404990673065186]

# %%
#Test texts bottom 5
X_test.tail(5)
# Out:
# 15756                headache cough runny nose sore throat
# 10575                          Runny noise and sore throat
# 18237           sore throat. white puss pockets on tonsils
# 5352     I am achy and conjested. Very low grade fever....
# 2602                              Diarrhea, stomach cramps
# Name: text, dtype: object

# %%
#Actual Classes of test text
y_test.tail(5)
# Out:
#        headache_Class  fever_Class  sore-throat_Class  \
# 15756               1            0                  1
# 10575               0            0                  1
# 18237               0            0                  1
# 5352                0            1                  0
# 2602                0            0                  0
#
#        anxiety-nervousness_Class  depression_Class  cough_Class  \
# 15756                          0                 0            1
# 10575                          0                 0            0
# 18237                          0                 0            0
# 5352                           0                 0            0
# 2602                           0                 0            0
#
#        abdominal-pain_Class  congestion_Class  myalgia_Class  back-pain_Class
# 15756                     0                 0              0                0
# 10575                     0                 0              0                0
# ...

# %%
#Model Predictions on the 5 classes per text
import pandas as pd
np.set_printoptions(formatter={'float_kind':'{:f}'.format})
print(varpdb[-5:])
# Out:
# [[0.920280 0.063951 0.981822 0.002036 0.000649 0.880147 0.008463 0.056658
#   0.067300 0.000744]
#  [0.004583 0.010466 0.969430 0.008158 0.003484 0.020040 0.013050 0.000851
#   0.012204 0.001345]
#  [0.004197 0.029718 0.990893 0.006869 0.001451 0.008253 0.006129 0.021076
#   0.002162 0.002234]
#  [0.009365 0.977611 0.019752 0.008652 0.030594 0.022588 0.002804 0.001897
#   0.060528 0.007087]
#  [0.007186 0.004339 0.017107 0.005408 0.017435 0.002002 0.983296 0.011122
#   0.005083 0.024022]]

# %%
varpdb = model.predict(test_data)
accuracyprodb=accuracy_score(test_labels,np.rint(varpdb))
print("Accuracy w/o gen data",accuracyprodb)

from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc

#auc = roc_auc_score(y_test,varpdb)

#print('AUC w/o gen data',auc)
# Out:
# Accuracy w/o gen data 0.8599092284417549

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()
metrics.multilabel_confusion_matrix(test_labels, np.rint(varpdb))
# Out:
# array([[[2516,   15],
#         [  32,  742]],
#
#        [[2538,   10],
#         [  32,  725]],
#
#        [[2518,   16],
#         [  33,  738]],
#
#        [[3051,    9],
#         [  54,  191]],
#
#        [[3208,    1],
#         [  40,   56]],
#
#        [[2519,    9],
#         [  23,  754]],
#
#        [[2929,   10],
#         [  54,  312]],
#
#        [[2813,   24],
#         [  35,  433]],
#
#        [[2792,   15],
#         [  54,  444]],
#
#        [[3039,   18],
#         [  48,  200]]])

# %%
met[0][1][1]/(met[0][1][0]+met[0][1][1])
# Out:
# 0.958656330749354

# %%
met[1][1][1]/(met[1][1][0]+met[1][1][1])
# Out:
# 0.9577278731836195

# %%
met = metrics.multilabel_confusion_matrix(test_labels, np.rint(varpdb))

class_names=[0,1] #name of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)

#create heatmap
sns.heatmap(pd.DataFrame(met[0]),annot=True,cmap="YlGnBu",fmt='g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for '+iclass[0],y=1.1,fontsize=20)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

recall = met[0][1][1]/(met[0][1][0]+met[0][1][1])

plt.suptitle(iclass[0]+' Recall score  '+str(recall),y=0.0,fontsize=15)
# Out:
# Text(0.5, 0.0, 'headache_Class Recall score  0.958656330749354')

# %%
met = metrics.multilabel_confusion_matrix(test_labels, np.rint(varpdb))

class_names=[0,1] #name of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)

#create heatmap
sns.heatmap(pd.DataFrame(met[1]),annot=True,cmap="YlGnBu",fmt='g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for '+iclass[1],y=1.1,fontsize=20)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

recall = met[1][1][1]/(met[1][1][0]+met[1][1][1])

plt.suptitle(iclass[1]+' Recall score  '+str(recall),y=0.0,fontsize=15)
# Out:
# Text(0.5, 0.0, 'fever_Class Recall score  0.9577278731836195')

# %%
met = metrics.multilabel_confusion_matrix(test_labels, np.rint(varpdb))

class_names=[0,1] #name of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)

#create heatmap
sns.heatmap(pd.DataFrame(met[2]),annot=True,cmap="YlGnBu",fmt='g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for '+iclass[2],y=1.1,fontsize=20)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

recall = met[2][1][1]/(met[2][1][0]+met[2][1][1])

plt.suptitle(iclass[2]+' Recall score  '+str(recall),y=0.0,fontsize=15)
# Out:
# Text(0.5, 0.0, 'sore-throat_Class Recall score  0.9571984435797666')

# %%
met = metrics.multilabel_confusion_matrix(test_labels, np.rint(varpdb))

class_names=[0,1] #name of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)

#create heatmap
sns.heatmap(pd.DataFrame(met[3]),annot=True,cmap="YlGnBu",fmt='g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for '+iclass[3],y=1.1,fontsize=20)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

recall = met[3][1][1]/(met[3][1][0]+met[3][1][1])

plt.suptitle(iclass[3]+' Recall score  '+str(recall),y=0.0,fontsize=15)
# Out:
# Text(0.5, 0.0, 'anxiety-nervousness_Class Recall score  0.7795918367346939')

# %%
met = metrics.multilabel_confusion_matrix(test_labels, np.rint(varpdb))

class_names=[0,1] #name of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)

#create heatmap
sns.heatmap(pd.DataFrame(met[4]),annot=True,cmap="YlGnBu",fmt='g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for '+iclass[4],y=1.1,fontsize=20)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

recall = met[4][1][1]/(met[4][1][0]+met[4][1][1])

plt.suptitle(iclass[4]+' Recall score  '+str(recall),y=0.0,fontsize=15)
# Out:
# Text(0.5, 0.0, 'depression_Class Recall score  0.5833333333333334')

# %%
met = metrics.multilabel_confusion_matrix(test_labels, np.rint(varpdb))

class_names=[0,1] #name of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)

#create heatmap
sns.heatmap(pd.DataFrame(met[5]),annot=True,cmap="YlGnBu",fmt='g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for '+iclass[5],y=1.1,fontsize=20)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

recall = met[5][1][1]/(met[5][1][0]+met[5][1][1])

plt.suptitle(iclass[5]+' Recall score  '+str(recall),y=0.0,fontsize=15)
# Out:
# Text(0.5, 0.0, 'cough_Class Recall score  0.9703989703989704')

# %%
met = metrics.multilabel_confusion_matrix(test_labels, np.rint(varpdb))

class_names=[0,1] #name of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)

#create heatmap
sns.heatmap(pd.DataFrame(met[6]),annot=True,cmap="YlGnBu",fmt='g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for '+iclass[6],y=1.1,fontsize=20)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

recall = met[6][1][1]/(met[6][1][0]+met[6][1][1])

plt.suptitle(iclass[6]+' Recall score  '+str(recall),y=0.0,fontsize=15)
# Out:
# Text(0.5, 0.0, 'abdominal-pain_Class Recall score  0.8524590163934426')

# %%
met = metrics.multilabel_confusion_matrix(test_labels, np.rint(varpdb))

class_names=[0,1] #name of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)

#create heatmap
sns.heatmap(pd.DataFrame(met[7]),annot=True,cmap="YlGnBu",fmt='g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for '+iclass[6],y=1.1,fontsize=20)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

recall = met[7][1][1]/(met[7][1][0]+met[7][1][1])

plt.suptitle(iclass[7]+' Recall score  '+str(recall),y=0.0,fontsize=15)
# Out:
# Text(0.5, 0.0, 'congestion_Class Recall score  0.9252136752136753')

# %%
met = metrics.multilabel_confusion_matrix(test_labels, np.rint(varpdb))

class_names=[0,1] #name of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)

#create heatmap
sns.heatmap(pd.DataFrame(met[8]),annot=True,cmap="YlGnBu",fmt='g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for '+iclass[8],y=1.1,fontsize=20)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

recall = met[8][1][1]/(met[8][1][0]+met[8][1][1])

plt.suptitle(iclass[8]+' Recall score  '+str(recall),y=0.0,fontsize=15)
# Out:
# Text(0.5, 0.0, 'myalgia_Class Recall score  0.891566265060241')

# %%
metrics.multilabel_confusion_matrix(test_labels, np.rint(varpdb))
# Out:
# array([[[445,   0],
#         [ 31,   0]],
#
#        [[  0, 168],
#         [  0, 308]],
#
#        [[469,   0],
#         [  7,   0]],
#
#        [[412,   0],
#         [ 64,   0]],
#
#        [[400,   0],
#         [ 76,   0]]])

# %%
#Depression
ds =(515+17)/(515+12+2+17)

#Headache accuracy
hs = (219+314)/(219+314+5+8)

#Drug use
drus = 545/(545+1)

#anxiety
ans = (479+51)/(479+51+5+11)
                
#dizyness
ds = (473+62)/(473+62+4+7)

print('Depression: ',ds)
print('Headache: ',hs)
print("Drugs: ",drus)
print('Anxiety: ',ans)
print('dizz: ',ds)
# Out:
# Depression:  0.9798534798534798
# Headache:  0.9761904761904762
# Drugs:  0.9981684981684982
# Anxiety:  0.9706959706959707
# dizz:  0.9798534798534798

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

cnf_matrix = metrics.multilabel_confusion_matrix(y_test, np.rint(varpdb))

class_names=[0,1] #name of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)

#create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix),annot=True,cmap="YlGnBu",fmt='g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for '+iclass+' model',y=1.1,fontsize=20)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

plt.suptitle(iclass+ ' Accuracy score '+str(accuracyprodb),y=0.0,fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-90b549fdd459> in <module>
#      14
#      15 #create heatmap
# ---> 16 sns.heatmap(pd.DataFrame(cnf_matrix),annot=True,cmap="YlGnBu",fmt='g')
#      17 ax.xaxis.set_label_position('top')
#      18 plt.tight_layout()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     495                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     496             else:
# --> 497                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     498
#     499         # For data is list-like, or Iterable (will consume into list)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     188     # by definition an array here
# ...

# %%
limes = ['burning sensation','my head hurts','i feel anxious and my head hurts a lot',
         'Im super depressed and i do alot of drugs now',
         'i touched the stove and now my hand is burning','I have a headache and im very dizzy','i burned my hand']

# %%
X_train.sample(10)
# Out:
# 22                           congestion, sinus pressure
# 8                                         deformed nose
# 36                                          Burned hand
# 9     I am about 7 weeks pregnant and have been thro...
# 24                                 bottom of foot hurts
# 56                                                burns
# 21    I have a cyst from an ingrown hair in my groin...
# 3                                       extreme fatigue
# 48    Lower back pain, smelly and cloudy urine, uret...
# 18                                      I have insomnia
# Name: text, dtype: object

# %%
data[data['text'].str.contains('Burns to pee')]

# %%
y_train.head()

# %%
newlines = list()
for line in limes:
    tokens = word_tokenize(line)
    
    #convert to lower case
    tokens = [w.lower() for w in tokens]
    
    #remove punctuation form each word
    table = str.maketrans('','',string.punctuation)
    stripped = [w.translate(table) for w in tokens]
    
    #remove remaining tokens that are not alphabetic
    words = [word for word in stripped if word.isalpha()]
   
    #filter out stop words
    stop_words=set(stopwords.words('english'))
    #words = [w for w in words if not w in stop_words]
    newlines.append(words)
#  

# Prepare the data
newdata = tokenizer.texts_to_sequences(newlines)
newdata = pad_sequences(newdata, maxlen=max_length,padding='post')

model.predict(newdata)
# Out:
# array([[0.01161918, 0.2523736 , 0.00494587, 0.01034614, 0.01105243],
#        [0.00341943, 0.8527868 , 0.00331685, 0.00562546, 0.00849369],
#        [0.05976844, 0.27593488, 0.00263703, 0.15895462, 0.00567308],
#        [0.67624515, 0.02423051, 0.00901791, 0.3161155 , 0.04365599],
#        [0.05094838, 0.03557765, 0.00398195, 0.05145305, 0.01302394],
#        [0.01058203, 0.7688727 , 0.02051771, 0.01505482, 0.80840826],
#        [0.03968197, 0.02744049, 0.00422743, 0.11620787, 0.01587424]],
#       dtype=float32)

# %%
limes = ['burning sensation',
         'my head hurts',
         'i feel anxious and my head hurts a lot',
         'Im super depressed and i do alot of drugs now',
         'i touched the stove and now my hand is burning',
         'I have a headache and im very dizzy',
         'i burned my hand']

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc



var_gen = model_gen.predict(test_data_gen)

accuracy_gen=accuracy_score(y_test,np.rint(var_gen))
print("Accuracy with gen data",accuracy_gen)

auc_gen = roc_auc_score(y_test,var_gen)

print('AUC with gen data',auc_gen)
# Out:
# Accuracy with gen data 0.8703703703703703
# AUC with gen data 0.9382716049382717

# %%
varpdb = model.predict(test_data)

accuracyprodb=accuracy_score(y_test,np.rint(varpdb))
print("Accuracy w/o gen data",accuracyprodb)

from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc

auc = roc_auc_score(y_test,varpdb)

print('AUC w/o gen data',auc)
# Out:
# Accuracy w/o gen data 0.8703703703703703
# AUC w/o gen data 0.9368998628257887

# %%
auc = roc_auc_score(y_test,var_gen)

auc
# Out:
# 0.9952284471143492

# %%
X_train.shape[0]
# Out:
# 1498

# %%
pdbcount = X_train.shape[0]
gencount = temp.shape[0]
nam = ['class','Prod Data Count','accuracy w/o gen data','auc w/o gen data','Generated Data Count','accuracy with gen data','auc with gen data']
x= pd.DataFrame([[clitem,pdbcount,accuracyprodb,auc,gencount,accuracy_gen,auc_gen]],columns=nam)
x
# Out:
#          class  Prod Data Count  accuracy w/o gen data  auc w/o gen data  \
# 0  pelvic-pain              126                0.87037            0.9369
#
#    Generated Data Count  accuracy with gen data  auc with gen data
# 0                     0                 0.87037           0.938272

# %%
gam = pd.read_csv('Models Performance.csv')

#gam.drop(gam.tail(2).index,inplace=True)

x = pd.concat([gam,x],axis=0)
x
# Out:
#                                       class  Prod Data Count  \
# 0                            abdominal-pain             1498
# 1                      animal-or-human-bite               36
# 2                                arm-injury               12
# 3                                  arm-pain              215
# 4                             asthma-attack               19
# 5                             athletes-foot                4
# 6                                 back-pain              932
# 7                bee-or-yellow-jacket-sting               15
# 8                         trouble-breathing              778
# 9                                      burn               40
# 10                               chest-pain             1034
# 11                                    cough             3018
# 12                                 headache             4394
# 13                                 diarrhea              998
# ...

# %%
x.to_csv('Models Performance.csv',index=False)

# %%
pd.read_csv('Models Performance.csv')
# Out:
#                                       class  Prod Data Count  \
# 0                            abdominal-pain             1498
# 1                      animal-or-human-bite               36
# 2                                arm-injury               12
# 3                                  arm-pain              215
# 4                             asthma-attack               19
# 5                             athletes-foot                4
# 6                                 back-pain              932
# 7                bee-or-yellow-jacket-sting               15
# 8                         trouble-breathing              778
# 9                                      burn               40
# 10                               chest-pain             1034
# 11                                    cough             3018
# 12                                 headache             4394
# 13                                 diarrhea              998
# ...

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

cnf_matrix = metrics.confusion_matrix(y_test, np.rint(var_gen))

class_names=[0,1] #name of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)

#create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix),annot=True,cmap="YlGnBu",fmt='g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for '+iclass+' model with generated data',y=1.1,fontsize=20)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

plt.suptitle(iclass+' Accuracy score w/ generated data '+str(accuracy_gen),y=0.0,fontsize=15)
# Out:
# Text(0.5, 0.0, 'flank-pain_Class Accuracy score w/ generated data 0.9065420560747663')

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

cnf_matrix = metrics.confusion_matrix(y_test, np.rint(varpdb))

class_names=[0,1] #name of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)

#create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix),annot=True,cmap="YlGnBu",fmt='g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for '+iclass+' model',y=1.1,fontsize=20)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

plt.suptitle(iclass+ ' Accuracy score '+str(accuracyprodb),y=0.0,fontsize=15)
# Out:
# Text(0.5, 0.0, 'flank-pain_Class Accuracy score 0.9158878504672897')

# %%
# importing all necessery modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
  
# Reads 'Youtube04-Eminem.csv' file 
game = temp
  
comment_words = ''
stopwords = set(STOPWORDS)
  
# iterate through the csv file
for val in game.text:
      
    # typecaste each val to string
    val = str(val)
  
    # split the value
    tokens = val.split()
      
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
  
# plot the WordCloud image                       
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
plt.show()

# %%
conv={"Fever":                                "fever",
	"Diarrhea":                             "diarrhea",
	"Throat Pain":                          "sore-throat",
	"Anxious or Nervous":                   "anxiety-nervousness",
	"Chest Lump (or Mass)":                 "skin-lump",
	"Head Pain (Headache)":                 "headache",
	"Swallowing Difficulty":                "TODO(bilal): what is it",
	"Ear Pain":                             "earache",
	"Anorexia":                             "TODO(bilal): what is it",
	"Finger Pain":                          "finger-pain",
	"Vomiting":                             "vomiting",
	"Nose Discharge":                       "runny-nose",
	"Sadness":                              "depression",
	"Belching (Burping, Eructation)":       "TODO(bilal): what is it",
	"Muscle Aches (Myalgia)":               "myalgia",
	"Nausea":                               "nausea",
	"Cough":                                "cough",
	"Chills":                               "chills",
	"Arm Numbness (or Tingling)":           "weakness-numbness",
	"Dizziness (Lightheaded - Woozy)":      "dizziness",
	"Eye Pain":                             "eye-or-eyelid-pain",
	"Eye Itching":                          "eye-eyelid-allergy-itching",
	"Dry Mouth":                            "TODO(bilal): what is it",
	"Fatigue":                              "weakness-and-fatigue",
	"Shortness of Breath":                  "trouble-breathing",
	"Loss or Decreased Sense of Taste":     "TODO(bilal): what is it",
	"Urine - Retention (Can't Pass Urine)": "TODO(bilal): what is it",
	"Nose Stuffiness or Congestion":        "congestion",
	"Abdomen Pain":                         "abdominal-pain",
	"Dyspareunia (Pain with Sex)":          "TODO(bilal): what is it",
	"Tinnitus":                             "tinnitus",
	"Face Pain":                            "face-injury-or-pain",
	"Urticaria (Hives)":                    "hives",
	"Psychiatric or Emotional Symptom":     "TODO(bilal): what is it",
	"Toe Injury":                           "toe-injury-or-pain",
	"Neck Pain":                            "neck-pain-or-stiffness",
	"Chest or Rib Pain":                    "chest-pain",
	"Skin Sore or Ulcer":                   "boil-or-skin-sore",
	"Lymph Node Swelling":                  "lymph-node-problem",
	"Redness or Rash - Localized":          "rash-or-redness-widespread-or-localized",
	"Ear Discharge (Leaking Fluid or Pus)": "ear-fullness-congestion-discharge",
	"Throat Swelling (Swollen Tonsils)":    "TODO(bilal): what is it",
	"Angry or Hostile Behavior":            "TODO(bilal): what is it",
	"Face Redness (or Rash)":               "face-redness-swelling-rash",
	"Back Pain":                            "back-pain",
	"Pelvic Pain":                          "pelvic-pain",
	"Knee Pain":                            "knee-pain-or-injury",
	"Stool - Blood in Stool":               "stools-blood-in",
	"Palpitations (Heart Pounding or Extra Beats)": "TODO(bilal): what is it",
	"Urine - Unusual Odor or Bad Smell":            "TODO(bilal): what is it",
	"Toe Pain":                                     "toe-injury-or-pain",
	"Head Injury":                                  "head-injury",
	"Foot Pain":                                    "foot-pain",
	"Mouth Pain":                                   "mouth-injury",
	"Arm Pain":                                     "arm-pain",
	"Knee Injury":                                  "knee-pain-or-injury",
	"Knee Redness (or Rash)":                       "rash-or-redness-widespread-or-localized",
	"Neck Stiffness (Trouble Bending or Turning)": "neck-pain-or-stiffness",
	"Ear Fullness or Congestion":                  "ear-fullness-congestion-discharge",
	"Face Numbness (or Tingling)":                 "weakness-numbness",
	"Muscle Jerks or Twitches":                    "TODO(bilal): what is it",
	"Leg Pain":                                    "leg-pain",
	"Hand Pain":                                   "hand-or-wrist-injury-or-pain",
	"Joint Pain":                                  "TODO(bilal): what is it",
	"Dry Skin":                                    "cracked-or-dry-skin",
	"Sneezing":                                    "sneezing",
	"Eye Watering":                                "TODO(bilal): what is it",
	"Eye Discharge (Cloudy Fluid or Pus)":         "eye-pus-discharge-redness",
	"Ankle Pain":                                  "foot-and-ankle-injury-or-ankle-pain",
	"Exposure to Heat / Hot Weather":              "heat-exposure",
	"Post-Op Symptom or Question":                 "post-op-symptoms-and-questions",
	"Decreased Fluid Intake (Drinking Less)":      "drinking-less",
	"Altered Mental Status":                       "TODO(bilal): what is it",
	"Bruising (Ecchymosis)":                       "TODO(bilal): what is it",
	"Eyelid Lump (or Bump)":                       "skin-lump",
	"Skin Moles or Growths":                       "skin-growth-or-mole",
	"Wrist Injury":                                "hand-or-wrist-injury-or-pain",
	"Hair Loss":                                   "hair-loss",
	"Weakness - Generalized":                      "weakness-and-fatigue",
	"Numbness (Loss of Sensation)":                "weakness-numbness",
	"Mouth Sores or Spots":                        "mouth-ulcers",
	"Arm Weakness":                                "TODO(bilal): what is it",
	"Urination Pain":                              "urination-pain",
	"Loss of Consciousness":                       "TODO(bilal): what is it",
	"Nosebleed":                                   "nosebleed",
	"Burn":                                        "burn",
	"Abdomen Redness (or Rash)":                   "rash-or-redness-widespread-or-localized",
	"Earwax":                                      "earwax-buildup",
	"Hematuria (Blood in Urine)":                  "urine-blood-in",
	"Hip Pain":                                    "hip-injury-or-pain",
	"Itching - Localized":                         "itch-localized-widespread",
	"Lip Redness, Rash, or Sore":                  "TODO(bilal): what is it",
	"Neck Swelling":                               "TODO(bilal): what is it",
	"Back Injury":                                 "TODO(bilal): what is it",
	"High Blood Pressure":                         "high-blood-pressure",
	"Puncture Wound":                              "puncture-wound",
	"Rectal Itching":                              "rectal-symptoms",
	"Wheezing":                                    "wheezing-other-than-asthma",
	"Scorpion Sting":                              "scorpion-sting-north-america",
	"Sunburn":                                     "sunburn",
	"Dandruff":                                    "TODO(bilal): what is it",
	"Leg Redness (or Rash)":                       "rash-or-redness-widespread-or-localized",
	"Scrotum Pain":                                "scrotal-pain-or-injury",
	"Nose Allergies (Hay Fever Symptoms)":         "nose-allergy",
	"Eye Foreign Body":                            "eye-foreign-body-or-injury",
	"Eye Redness":                                 "eye-pus-discharge-redness",
	"Leg Swelling":                                "leg-swelling",
	"Vision Lost":                                 "vision-loss-or-change",
	"Poisoning or Overdose":                       "TODO(bilal): what is it",
	"Chest Redness (or Rash)":                     "rash-or-redness-widespread-or-localized",
	"Sweating":                                    "sweating",
	"Buttock Pain":                                "TODO(bilal): what is it",
	"Vision Blurred (blurry or hazy)":             "vision-loss-or-change",
	"Arm Injury":                                  "arm-injury",
	"Tooth or Gum Pain":                           "toothache",
	"Wrist Pain":                                  "hand-or-wrist-injury-or-pain",
	"Impotence (Erectile Dysfunction)":            "TODO(bilal): what is it",
	"Stool - Unusual Color":                       "TODO(bilal): what is it",
	"Finger Blueness":                             "TODO(bilal): what is it",
	"Insomnia (Trouble Sleeping)":                 "insomnia",
	"Arm Redness (or Rash)":                       "rash-or-redness-widespread-or-localized",
	"Hypoxia":                                     "TODO(bilal): what is it",
	"Jaw Pain":                                    "TODO(bilal): what is it",
	"Breast Pain":                                 "breast-symptoms",
	"Constipation":                                "constipation",
	"Crying or Fussy Baby or Infant":              "crying-baby",
	"Buttock Redness (or Rash)":                   "rash-or-redness-widespread-or-localized",
	"Abdomen Swelling":                            "TODO(bilal): what is it",
	"Hiccups":                                     "TODO(bilal): what is it",
	"Loss or Decreased Sense of Smell":            "TODO(bilal): what is it",
	"Throat White Spots (Pus on Tonsils)":         "TODO(bilal): what is it",
	"Shoulder Pain":                               "shoulder-pain-or-injury",
	"Jaundice (Yellow Color of Eyes)":             "jaundice",
	"Nose Pain":                                   "TODO(bilal): what is it",
	"Groin Itching":                               "itch-localized-widespread",
	"Bee, Wasp, or Yellow Jacket Sting":           "bee-or-yellow-jacket-sting",
	"Breast Redness (or Rash)":                    "breast-symptoms",
	"Hand Swelling":                               "TODO(bilal): what is it",
	"Vaginal Discharge":                           "vaginal-discharge",
	"Unsteady Walking (Ataxia)":                   "TODO(bilal): what is it",
	"Urination Frequency":                         "frequent-urination",
	"Uvula Swelling":                              "TODO(bilal): what is it",
	"Vertigo (Spinning - Tilting)":                "TODO(bilal): what is it",
	"Underweight":                                 "TODO(bilal): what is it",
	"Urine - Unusual Color":                       "TODO(bilal): what is it",
	"Vaginal Bleeding":                            "vaginal-bleeding",
	"Vaginal Pain or Irritation":                  "TODO(bilal): what is it",
	"Vaginal Dryness":                             "TODO(bilal): what is it",
	"Hoarseness":                                  "hoarseness",
	"Fall":                                        "TODO(bilal): what is it",
	"Croupy or Barking Cough":                     "TODO(bilal): what is it",
	"Amenorrhea":                                  "menstrual-period-missed-or-late",
	"Abrasion or Scratch":                         "TODO(bilal): what is it",
	"Flank Pain":                                  "flank-pain",
	"Malaise":                                     "TODO(bilal): what is it",
	"Thirsty":                                     "TODO(bilal): what is it",
	"Leg Lump (or Mass)":                          "skin-lump",
	"Rash - Purple Spots or Dots":                 "rash-or-redness-widespread-or-localized",
	"Back Redness (or Rash)":                      "rash-or-redness-widespread-or-localized",
	"Foot Numbness (or Tingling)":                 "weakness-numbness",
	"Tingling (Paresthesia)":                      "TODO(bilal): what is it",
	"Cut or Laceration":                           "skin-injury",
	"Finger Injury":                               "finger-injury",
	"Strange or Bizarre Behavior":                 "TODO(bilal): what is it",
	"Hallucinations":                              "TODO(bilal): what is it",
	"Slurred Speech (or Aphasia)":                 "TODO(bilal): what is it",
	"Cardiorespiratory Arrest":                    "TODO(bilal): what is it",
	"Sleepiness or Sleeping Too Much":             "TODO(bilal): what is it",
	"Arm Crooked or Deformed":                     "TODO(bilal): what is it",
	"Rectal Bleeding":                             "rectal-bleeding",
	"Menstrual Period - Missed or Late":           "menstrual-period-missed-or-late",
	"Pregnant - Contractions":                     "TODO(bilal): what is it",
	"Suicidal Thinking":                           "TODO(bilal): what is it",
	"Foot Itching":                                "itch-localized-widespread",
	"Yawning":                                     "TODO(bilal): what is it",
	"Eye Dryness":                                 "TODO(bilal): what is it",
	"Tachycardia (Fast Heart Beat)":               "TODO(bilal): what is it",
	"Tick Bite":                                   "tick-bite",
	"Elbow Pain":                                  "elbow-pain",
	"Knee Swelling":                               "TODO(bilal): what is it",
	"Low Blood Pressure":                          "TODO(bilal): what is it",
	"Pale Skin":                                   "TODO(bilal): what is it",
	"Smoker / Smoking Problem (Tobacco)":          "TODO(bilal): what is it",
	"Throat Redness (or Red Spots)":               "TODO(bilal): what is it",
	"Pregnancy Symptom or Question":               "TODO(bilal): what is it",
	"Flatulence (Passing Gas)":                    "TODO(bilal): what is it",
	"Swallowed Foreign Body":                      "TODO(bilal): what is it",
	"Ankle Injury":                                "foot-and-ankle-injury-or-ankle-pain",
	"Foot Injury":                                 "foot-and-ankle-injury-or-ankle-pain",
	"Lips Dry, Cracked, or Chapped":               "cracked-or-dry-skin",
	"Coughing Up Blood":                           "TODO(bilal): what is it",
	"Ear Itching":                                 "itch-localized-widespread",
	"Alcohol Use or Abuse":                        "alcohol-use-abuse",
	"Lip or Face Blueness":                        "TODO(bilal): what is it",
	"Leg Weakness":                                "weakness-numbness",
	"Ankle Swelling":                              "TODO(bilal): what is it",
	"Hyperglycemia":                               "TODO(bilal): what is it",
	"Head Itching":                                "itch-localized-widespread",
	"Penis Redness (or Rash)":                     "rash-or-redness-widespread-or-localized",
	"Foot Weakness":                               "weakness-numbness",
	"Skin Blister(s)":                             "blisters",
	"Ear Bleeding":                                "TODO(bilal): what is it",
	"Urine - Incontinence (Can't Control, Leaking)": "TODO(bilal): what is it",
	"Lip Swelling":                        "TODO(bilal): what is it",
	"Eyelid Swelling":                     "eyelid-swelling",
	"Eyelid Twitch or Spasm":              "TODO(bilal): what is it",
	"Eyelid Bruising (\"Black Eye\")":     "TODO(bilal): what is it",
	"Rectal Worms":                        "rectal-symptoms",
	"Head Lice":                           "head-lice",
	"Vulva Swelling":                      "TODO(bilal): what is it",
	"Gum Bleeding":                        "TODO(bilal): what is it",
	"Penis Pain":                          "TODO(bilal): what is it",
	"Skin Abscess (or Boil)":              "boil-or-skin-sore",
	"Psychosexual Symptom or Question":    "TODO(bilal): what is it",
	"Vomiting Blood":                      "vomiting",
	"Tachypnea (Fast Breathing)":          "TODO(bilal): what is it",
	"Scrotum Swelling":                    "scrotal-swelling",
	"Stridor":                             "TODO(bilal): what is it",
	"Hearing Loss":                        "TODO(bilal): what is it",
	"Foot Swelling":                       "TODO(bilal): what is it",
	"Finger Swelling":                     "TODO(bilal): what is it",
	"Rectal Incontinence (Leaking Stool)": "TODO(bilal): what is it",
	"Face Swelling":                       "face-redness-swelling-rash",
	"Eye Bleeding":                        "TODO(bilal): what is it",
	"Elbow Swelling":                      "TODO(bilal): what is it",
	"Delusions":                           "TODO(bilal): what is it",
	"Coma":                                "TODO(bilal): what is it",
	"Slow Heart Beat (Bradycardia)":       "TODO(bilal): what is it",
	"Rectal Pain":                         "rectal-symptoms",
	"Overweight":                          "TODO(bilal): what is it",
	"Nose Swelling":                       "TODO(bilal): what is it",
	"Loss or Decreased Sex Drive":         "TODO(bilal): what is it",
	"Memory Loss (or Impairment)":         "TODO(bilal): what is it",
	"Limping":                             "TODO(bilal): what is it",
	"Joint Swelling":                      "TODO(bilal): what is it",
	"Jaw Swelling":                        "TODO(bilal): what is it",
	"Agitation":                           "TODO(bilal): what is it",
	"Hand Redness (or Rash)":              "rash-or-redness-widespread-or-localized",
	"Redness or Rash - Widespread":        "rash-or-redness-widespread-or-localized",
	"Hand Injury":                         "hand-or-wrist-injury-or-pain",
	"Lack of Weight Gain":                 "TODO(bilal): what is it",
	"Hip Swelling":                        "TODO(bilal): what is it",
	"Tremors or Trembling":                "TODO(bilal): what is it",
	"Hernia":                              "TODO(bilal): what is it",
	"Hand Numbness (or Tingling)":         "TODO(bilal): what is it",
	"Ankle Redness (or Rash)":             "rash-or-redness-widespread-or-localized",
	"Snake Bite":                          "snake-bite",
	"Buttock Lump (or Mass)":              "skin-lump",
	"Rectal Lump (or Mass)":               "skin-lump",
	"Abdomen Lump (or Mass)":              "skin-lump",
	"Photophobia":                         "TODO(bilal): what is it",
	"Ear Pulling":                         "TODO(bilal): what is it",
	"Ear Redness (or Rash)":               "rash-or-redness-widespread-or-localized",
	"Tongue Swelling":                     "TODO(bilal): what is it",
	"Leg Injury":                          "leg-injury",
	"Breast / Nipple Discharge (Leaking Fluid or Pus)": "breast-symptoms",
	"Apnea (stopped breathing for a short while)":      "TODO(bilal): what is it",
	"Eye Injury":                                    "eye-foreign-body-or-injury",
	"Foot Redness (or Rash)":                        "rash-or-redness-widespread-or-localized",
	"Toe Swelling":                                  "TODO(bilal): what is it",
	"Arm Swelling":                                  "TODO(bilal): what is it",
	"Behavioral Problem":                            "TODO(bilal): what is it",
	"Penis Discharge (Leaking Fluid or Pus)":        "TODO(bilal): what is it",
	"Weight Loss":                                   "TODO(bilal): what is it",
	"Tooth is Loose":                                "TODO(bilal): what is it",
	"Weight Gain":                                   "TODO(bilal): what is it",
	"Breast Swelling":                               "breast-symptoms",
	"Double Vision":                                 "vision-loss-or-change",
	"Eyelid Drooping (Ptosis)":                      "TODO(bilal): what is it",
	"Lymph Node Pain (or Tenderness)":               "lymph-node-problem",
	"Wound Bleeding":                                "TODO(bilal): what is it",
	"Wound Redness":                                 "wound-infection",
	"Drug Use or Abuse":                             "drug-use-and-abuse",
	"Vagina Foreign Body":                           "TODO(bilal): what is it",
	"Wound Pain":                                    "wound-infection",
	"Shoulder Crooked or Deformed":                  "shoulder-pain-or-injury",
	"Hip Crooked or Deformed":                       "TODO(bilal): what is it",
	"Hip Injury":                                    "hip-injury-or-pain",
	"Scrotum Redness (or Rash)":                     "rash-or-redness-widespread-or-localized",
	"Groin Redness (or Rash)":                       "rash-or-redness-widespread-or-localized",
	"Toe Redness (or Rash)":                         "rash-or-redness-widespread-or-localized",
	"Nose Redness (or Rash)":                        "rash-or-redness-widespread-or-localized",
	"Jaw Redness (or Rash)":                         "rash-or-redness-widespread-or-localized",
	"Head Redness (or Rash)":                        "rash-or-redness-widespread-or-localized",
	"Wrist Redness (or Rash)":                       "rash-or-redness-widespread-or-localized",
	"Shoulder Redness (or Rash)":                    "rash-or-redness-widespread-or-localized",
	"Neck Redness (or Rash)":                        "rash-or-redness-widespread-or-localized",
	"Hip Redness (or Rash)":                         "rash-or-redness-widespread-or-localized",
	"Finger Redness (or Rash)":                      "rash-or-redness-widespread-or-localized",
	"Elbow Redness (or Rash)":                       "rash-or-redness-widespread-or-localized",
	"Flank Redness (or Rash)":                       "rash-or-redness-widespread-or-localized",
	"Rectal Redness (or Rash)":                      "rash-or-redness-widespread-or-localized",
	"Bad Breath (Unusual Odor or Bad Smell)":        "TODO(bilal): what is it",
	"Tongue Pain":                                   "TODO(bilal): what is it",
	"Lip Pain":                                      "TODO(bilal): what is it",
	"Back Lump (or Mass)":                           "skin-lump",
	"Penis Swelling":                                "TODO(bilal): what is it",
	"Groin Pain":                                    "TODO(bilal): what is it",
	"Rectal Discharge (Leaking Fluid or Pus)":       "rectal-symptoms",
	"Asthma Attack":                                 "asthma-attack",
	"Finger Numbness (or Tingling)":                 "TODO(bilal): what is it",
	"Belly Button Swelling":                         "TODO(bilal): what is it",
	"Vomiting Bile (Green)":                         "vomiting",
	"Exposure to Cold / Cold Weather":               "TODO(bilal): what is it",
	"Toe Blueness":                                  "TODO(bilal): what is it",
	"Nose Crooked or Deformed":                      "TODO(bilal): what is it",
	"Difficulty Concentrating":                      "TODO(bilal): what is it",
	"Penis Foreskin Stuck":                          "TODO(bilal): what is it",
	"Shoulder Injury":                               "shoulder-pain-or-injury",
	"Vulva Redness (or Rash)":                       "rash-or-redness-widespread-or-localized",
	"Leg Numbness (or Tingling)":                    "weakness-numbness",
	"Decreased Urination":                           "TODO(bilal): what is it",
	"Vulva Itching":                                 "vulva-itching",
	"Seizure":                                       "TODO(bilal): what is it",
	"Wrist Swelling":                                "TODO(bilal): what is it",
	"Groin Swelling":                                "TODO(bilal): what is it",
	"Head Lump (or Mass)":                           "skin-lump",
	"Stool - Black Color":                           "TODO(bilal): what is it",
	"Snoring":                                       "TODO(bilal): what is it",
	"Shoulder Swelling":                             "TODO(bilal): what is it",
	"Breast Lump (or Mass)":                         "breast-symptoms",
	"Ear Swelling":                                  "TODO(bilal): what is it",
	"Gum Swelling":                                  "TODO(bilal): what is it",
	"Drooling":                                      "TODO(bilal): what is it",
	"Nose Foreign Body":                             "TODO(bilal): what is it",
	"Forehead Pain":                                 "TODO(bilal): what is it",
	"Toe Numbness (or Tingling)":                    "TODO(bilal): what is it",
	"Face Weakness":                                 "weakness-numbness",
	"Forehead Injury":                               "TODO(bilal): what is it",
	"Arm Pit Pain":                                  "TODO(bilal): what is it",
	"Scrotum Itching":                               "itch-localized-widespread",
	"Itching - Widespread":                          "itch-localized-widespread",
	"Suicide Attempt":                               "TODO(bilal): what is it",
	"Penis Bleeding":                                "TODO(bilal): what is it",
	"Visual Floater":                                "TODO(bilal): what is it",
	"Insect Bite or Sting":                          "insect-bite",
	"Electric Shock":                                "TODO(bilal): what is it",
	"Penis Growth, Sore, or Wart":                   "TODO(bilal): what is it",
	"Tooth or Gum Injury":                           "tooth-injury",
	"Vision Blurred (Decreased/Lost)":               "vision-loss-or-change",
	"Forehead Redness (or Rash)":                    "rash-or-redness-widespread-or-localized",
	"Restlessness (Can't Sit or Stay Still)":        "TODO(bilal): what is it",
	"Exposure to Infection":                         "TODO(bilal): what is it",
	"Body Piercing Symptom or Question":             "TODO(bilal): what is it",
	"Belly Button Pain":                             "TODO(bilal): what is it",
	"Hypothermia":                                   "TODO(bilal): what is it",
	"Motor Vehicle Accident":                        "TODO(bilal): what is it",
	"Chest or Rib Injury":                           "TODO(bilal): what is it",
	"Arm Pit Lump (or Mass)":                        "TODO(bilal): what is it",
	"Alcohol Intoxication":                          "TODO(bilal): what is it",
	"Animal Bite or Scratch":                        "animal-or-human-bite",
	"Nose Injury":                                   "TODO(bilal): what is it",
	"Breastfeeding Symptom or Question":             "breast-symptoms",
	"Arm Pit Redness (or Rash)":                     "rash-or-redness-widespread-or-localized",
	"Paranoia":                                      "TODO(bilal): what is it",
	"Allergic Reaction":                             "TODO(bilal): what is it",
	"Spider Bite":                                   "spider-bite",
	"Neck Injury":                                   "TODO(bilal): what is it",
	"Vaginal Discharge - Unusual Odor or Bad Smell": "TODO(bilal): what is it",
	"Hand Weakness":                                 "TODO(bilal): what is it",
	"Elbow Injury":                                  "TODO(bilal): what is it",
	"Eyelid Pain (or Tender to Touch)":              "eye-or-eyelid-pain",
	"Foot Unusual Odor or Bad Smell":                "athletes-foot",
	"Rectal Growth, Sore, or Wart":                  "TODO(bilal): what is it",
	"Stab Wound":                                    "TODO(bilal): what is it",
	"Foot Lump (or Mass)":                           "TODO(bilal): what is it",
	"Choking":                                       "TODO(bilal): what is it",
	"Semen - Blood in Semen":                        "TODO(bilal): what is it",
	"Arm Lump (or Mass)":                            "TODO(bilal): what is it",
	"Ear Lump (or Bump)":                            "TODO(bilal): what is it",
	"Vulva Growth, Sore, or Wart":                   "TODO(bilal): what is it",
	"Breast Engorgement":                            "breast-symptoms",
	"Mouth or Tongue Bleeding":                      "TODO(bilal): what is it",
	"Blast Injury (Explosion)":                      "TODO(bilal): what is it",
	"Skin Foreign Body":                             "TODO(bilal): what is it",
	"Spitting Up Milk (reflux in baby or infant)":   "TODO(bilal): what is it",
	"Travel to High Altitude":                       "TODO(bilal): what is it",
	"Eyelid Redness (or Rash)":                      "TODO(bilal): what is it",
	"Nightmare (Bad Dream)":                         "TODO(bilal): what is it",
	"Belly Button Redness (or Rash)":                "TODO(bilal): what is it",
	"Face Lump (or Mass)":                           "TODO(bilal): what is it",
	"Forehead Swelling":                             "TODO(bilal): what is it",
	"Visual Flashing Lights":                        "TODO(bilal): what is it",
	"Buttock Injury":                                "TODO(bilal): what is it",
	"Breast / Nipple Bleeding":                      "TODO(bilal): what is it",
	"Wound Swelling":                                "wound-infection",
	"Vulva Pain":                                    "TODO(bilal): what is it",
	"Un-protected Sexual Intercourse":               "TODO(bilal): what is it",
	"Hypoglycemia":                                  "TODO(bilal): what is it",
	"Head Bleeding":                                 "TODO(bilal): what is it",
	"Mouth or Tongue Injury":                        "TODO(bilal): what is it",
	"Toenail Looks Cloudy":                          "TODO(bilal): what is it",
	"Ear Injury":                                    "TODO(bilal): what is it",
	"Face Injury":                                   "TODO(bilal): what is it"}
